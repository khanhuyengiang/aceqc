# %%
import numpy as np
from scipy.linalg import expm
from qutip import *
from qsq_protocol import average_fidelity, plus_state, minus_state

# %%
# Function 1: Calculate U from theta1, theta2, theta3
def compute_U(theta1, theta2, theta3):
    # Constructing the unitary matrix U(θ1, θ2, θ3)
    U = np.array([
        [np.exp(1j * theta1) * np.cos(theta2), np.exp(1j * theta3) * np.sin(theta2)],
        [np.exp(-1j * theta3) * np.sin(theta2), np.exp(-1j * theta1) * np.cos(theta2)]
    ])
    return U

# Function 2: Given a matrix U, compute theta1, theta2, theta3
def decompose_U(U):
    # Extracting theta2 from the sine elements (sin(θ2) term)
    theta2 = np.arcsin(np.abs(U[1, 0]))  # Using the off-diagonal elements
    
    # Using the real part of U[0, 0] and U[1, 1] to extract theta1 and theta3
    cos_theta2 = np.cos(theta2)
    theta1 = np.angle(U[0, 0])  # The phase angle of U[0, 0] gives θ1
    theta3 = np.angle(U[0, 1])  # The phase angle of U[0, 1] gives θ3
    
    return theta1, theta2, theta3

# Example usage:
theta1, theta2, theta3 = np.pi/2, np.pi/3, np.pi/6
print(theta1,theta2,theta3)
U = compute_U(theta1, theta2, theta3)
print("U:", U)

# Decompose U back into theta1, theta2, theta3
theta1_reconstructed, theta2_reconstructed, theta3_reconstructed = decompose_U(U)
print(f"Reconstructed theta1: {theta1_reconstructed}, theta2: {theta2_reconstructed}, theta3: {theta3_reconstructed}")
# Out:
# 1.5707963267948966 1.0471975511965976 0.5235987755982988
# U: [[3.061617e-17+0.5j       7.500000e-01+0.4330127j]
#  [7.500000e-01-0.4330127j 3.061617e-17-0.5j      ]]
# Reconstructed theta1: 1.5707963267948966, theta2: 1.0471975511965976, theta3: 0.5235987755982988

# %%
rho_exp = rand_dm(2)
M_exp = ket2dm(rand_ket(2))
gate_exp = rand_unitary(2)
average_fidelity(rho_exp,gate_exp,M_exp)
# Out:
# np.float64(0.753065)

# %%
import numpy as np
from scipy.optimize import minimize

# Assuming you have a compute_U function and average_fidelity function defined

# Define the objective function to minimize
def objective_function(params, rho_exp, gate_exp, M_exp):
    # Unpack the parameters (theta1, theta2, theta3)
    theta1, theta2, theta3 = params
    
    # Compute the unitary operator U based on theta1, theta2, theta3
    U = Qobj(compute_U(theta1, theta2, theta3))
    
    # Compute the objective function (average fidelity)
    return 1 - average_fidelity(U @ rho_exp @ U.dag(), U @ gate_exp @  U.dag(), U @ M_exp @  U.dag())

# Example fixed matrices (rho_exp, gate_exp, M_exp)
rho_exp = rand_dm(2)
M_exp = rand_dm(2)
gate_exp = rand_unitary(2)
print(average_fidelity(rho_exp,gate_exp,M_exp))

# Initial guess for the parameters (theta1, theta2, theta3)
initial_guess = [0.1, 0.2, 0.3]

# Perform the optimization
result = minimize(
    objective_function, 
    initial_guess, 
    args=(rho_exp, gate_exp, M_exp),  # Pass the fixed matrices as extra arguments
    method='BFGS'  # You can change this to another method if needed
)

# Display the result
if result.success:
    print("Optimal parameters:", result.x)
    print("Objective function value at optimal parameters:", 1 - result.fun)
else:
    print("Optimization failed:", result.message)
# Out:
# 0.764242
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.61498603+0.00000000e+00j 0.64368187+9.94039651e-03j]
#  [0.64368187-9.94039651e-03j 0.69813129-1.38777878e-17j]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 27
#      24 initial_guess = [0.1, 0.2, 0.3]
#      26 # Perform the optimization
# ---> 27 result = minimize(
#      28     objective_function,
#      29     initial_guess,
#      30     args=(rho_exp, gate_exp, M_exp),  # Pass the fixed matrices as extra arguments
#      31     method='BFGS'  # You can change this to another method if needed
#      32 )
#      34 # Display the result
#      35 if result.success:
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_minimize.py:780, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     778     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     779 elif meth == 'bfgs':
# --> 780     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     781 elif meth == 'newton-cg':
#     782     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     783                              **options)
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_optimize.py:1416, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, workers, **unknown_options)
#    1413 if maxiter is None:
#    1414     maxiter = len(x0) * 200
# -> 1416 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1417                               finite_diff_rel_step=finite_diff_rel_step,
#    1418                               workers=workers)
#    1420 f = sf.fun
#    1421 myfprime = sf.grad
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_differentiable_functions.py:274, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     272 # Initial function evaluation
#     273 self._nfev = 0
# --> 274 self._update_fun()
#     276 # Initial gradient evaluation
#     277 self._wrapped_grad = _ScalarGradWrapper(
#     278     grad,
#     279     fun=self._wrapped_fun,
#     280     args=args,
#     281     finite_diff_options=finite_diff_options,
#     282 )
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File d:\Program Files\python\Lib\site-packages\scipy\_lib\_util.py:583, in _ScalarFunctionWrapper.__call__(self, x)
#     580 def __call__(self, x):
#     581     # Send a copy because the user may overwrite it.
#     582     # The user of this class might want `x` to remain unchanged.
# --> 583     fx = self.f(np.copy(x), *self.args)
#     584     self.nfev += 1
#     586     # Make sure the function returns a true scalar
#
# Cell In[4], line 15, in objective_function(params, rho_exp, gate_exp, M_exp)
#      12 U = Qobj(compute_U(theta1, theta2, theta3))
#      14 # Compute the objective function (average fidelity)
# ---> 15 return 1 - average_fidelity(U @ rho_exp @ U.dag(), U @ gate_exp @  U.dag(), U @ M_exp @  U.dag())
#
# File d:\Code\aceqc\qsq_protocol.py:85, in average_fidelity(rho, gate, M)
#      83 if M_fid < 0 or M_fid > 1:
#      84     print(M)
# ---> 85     raise ValueError(f"Invalid fidelity for M: {M_fid}. Fidelity values must be between 0 and 1. "
#      86                      "Check the M fidelity calculation and the input matrix M.")
#      88 # Compute average fidelity
#      89 avg_fid = (rho_fid + gate_fid + M_fid) / 3
#
# ValueError: Invalid fidelity for M: 1.1402809004461476. Fidelity values must be between 0 and 1. Check the M fidelity calculation and the input matrix M.

# %%
# Define the matrix as a NumPy array
matrix = np.array([[0.61498603+0.00000000e+00j, 0.64368187+9.94039651e-03j],
                   [0.64368187-9.94039651e-03j, 0.69813129-1.38777878e-17j]])

# Convert the matrix to a Qobj
qobj_matrix = Qobj(matrix)

# %%
fidelity

# %%
# Initial guess for the parameters (theta1, theta2, theta3)
eigenvalues, eigenstates = M_exp.eigenstates()
U_guess = eigenstates[0] @ plus_state.dag() - 1j * eigenstates[1] @ minus_state.dag()
initial_guess = decompose_U(U_guess)

# Perform the optimization
result = minimize(
    objective_function, 
    initial_guess, 
    args=(rho_exp, gate_exp, M_exp),  # Pass the fixed matrices as extra arguments
    method='COBYLA'  # You can change this to another method if needed
)

# Display the result
if result.success:
    print("Optimal parameters:", result.x)
    print("Objective function value at optimal parameters:", 1 - result.fun)
else:
    print("Optimization failed:", result.message)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       4 initial_guess = decompose_U(U_guess)
#       6 # Perform the optimization
# ----> 7 result = minimize(
#       8     objective_function,
#       9     initial_guess,
#      10     args=(rho_exp, gate_exp, M_exp),  # Pass the fixed matrices as extra arguments
#      11     method='COBYLA'  # You can change this to another method if needed
#      12 )
#      14 # Display the result
#      15 if result.success:
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_minimize.py:791, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     788     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     789                         **options)
#     790 elif meth == 'cobyla':
# --> 791     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     792                            bounds=bounds, **options)
#     793 elif meth == 'cobyqa':
#     794     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     795                            **options)
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_cobyla_py.py:246, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, f_target, callback, bounds, **unknown_options)
#     243 def _jac(x, *args):
#     244     return None
# --> 246 sf = _prepare_scalar_function(fun, x0, args=args, jac=_jac)
#     248 if callback is not None:
#     249     sig = signature(callback)
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_differentiable_functions.py:274, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     272 # Initial function evaluation
#     273 self._nfev = 0
# --> 274 self._update_fun()
#     276 # Initial gradient evaluation
#     277 self._wrapped_grad = _ScalarGradWrapper(
#     278     grad,
#     279     fun=self._wrapped_fun,
#     280     args=args,
#     281     finite_diff_options=finite_diff_options,
#     282 )
#
# File d:\Program Files\python\Lib\site-packages\scipy\optimize\_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File d:\Program Files\python\Lib\site-packages\scipy\_lib\_util.py:583, in _ScalarFunctionWrapper.__call__(self, x)
#     580 def __call__(self, x):
#     581     # Send a copy because the user may overwrite it.
#     582     # The user of this class might want `x` to remain unchanged.
# --> 583     fx = self.f(np.copy(x), *self.args)
#     584     self.nfev += 1
#     586     # Make sure the function returns a true scalar
#
# Cell In[4], line 15, in objective_function(params, rho_exp, gate_exp, M_exp)
#      12 U = Qobj(compute_U(theta1, theta2, theta3))
#      14 # Compute the objective function (average fidelity)
# ---> 15 return 1 - average_fidelity(U @ rho_exp @ U.dag(), U @ gate_exp @  U.dag(), U @ M_exp @  U.dag())
#
# File d:\Code\aceqc\qsq_protocol.py:74, in average_fidelity(rho, gate, M)
#      72 # Check if any fidelity is out of the [0, 1] range
#      73 if rho_fid < 0 or rho_fid > 1:
# ---> 74     raise ValueError(f"Invalid fidelity for rho: {rho_fid}. Fidelity values must be between 0 and 1. "
#      75                      "Check the rho fidelity calculation and the input state.")
#      77 if gate_fid < 0 or gate_fid > 1:
#      78     raise ValueError(f"Invalid fidelity for gate: {gate_fid}. Fidelity values must be between 0 and 1. "
#      79                      "Check the gate fidelity calculation and the input gate.")
#
# ValueError: Invalid fidelity for rho: 1.0105258499331742. Fidelity values must be between 0 and 1. Check the rho fidelity calculation and the input state.

# %%
evalue[0] * estate[0] @ estate[0].dag()  + evalue[1] * estate[1] @ estate[1].dag()
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[ 0.33871197+0.00000000e+00j -0.16614519-3.76660949e-01j]
#  [-0.16614519+3.76660949e-01j  0.66128803-2.77555756e-17j]]

# %%
U_guess = estate[0] @ plus_state.dag() - 1j*estate[1] @ minus_state.dag()
U_guess
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[-0.58412028-0.39850157j -0.58412028+0.39850157j]
#  [ 0.37360916+0.60034673j -0.69526506+0.12886618j]]
